# %% [markdown]
# Importing Libraries and Datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/new_data.csv'

try:
    data = pd.read_csv('/content/drive/My Drive/new_data.csv')

    # 4. Display the first few rows (as in your original code)
    print("Successfully read the file. Here's the head:")
    print(data.head())

except FileNotFoundError:
    print(f"Error: File not found at path: {file_path}")
    print("Please double-check the 'file_path' variable and make sure it's correct.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: File not found at path: /content/drive/My Drive/new_data.csv
# Please double-check the 'file_path' variable and make sure it's correct.

# %%
data = pd.read_csv('new_data.csv')
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1051222 entries, 0 to 1051221
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   step            1051222 non-null  int64
#  1   type            1051222 non-null  object
#  2   amount          1051222 non-null  float64
#  3   nameOrig        1051221 non-null  object
#  4   oldbalanceOrg   1051221 non-null  float64
#  5   newbalanceOrig  1051221 non-null  float64
#  6   nameDest        1051221 non-null  object
#  7   oldbalanceDest  1051221 non-null  float64
#  8   newbalanceDest  1051221 non-null  float64
#  9   isFraud         1051221 non-null  float64
#  10  isFlaggedFraud  1051221 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 88.2+ MB

# %%
data.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  1.051222e+06  1.051222e+06   1.051221e+06    1.051221e+06
# mean   2.713748e+01  1.586017e+05   8.736904e+05    8.934873e+05
# std    1.597176e+01  2.652303e+05   2.969525e+06    3.006042e+06
# min    1.000000e+00  1.000000e-01   0.000000e+00    0.000000e+00
# 25%    1.500000e+01  1.212758e+04   0.000000e+00    0.000000e+00
# 50%    2.000000e+01  7.621084e+04   1.601418e+04    0.000000e+00
# 75%    3.900000e+01  2.136583e+05   1.366530e+05    1.745550e+05
# max    9.500000e+01  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    1.051221e+06    1.051221e+06  1.051221e+06       1051221.0
# mean     9.779336e+05    1.113781e+06  1.090161e-03             0.0
# std      2.296353e+06    2.416073e+06  3.299960e-02             0.0
# min      0.000000e+00    0.000000e+00  0.000000e+00             0.0
# ...

# %% [markdown]
# Data Visualization

# %%
obj = (data.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:", len(object_cols))

int_ = (data.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:", len(num_cols))

fl = (data.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:", len(fl_cols))
# Out:
# Categorical variables: 3
# Integer variables: 1
# Float variables: 7

# %%
sns.countplot(x='type', data=data)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.barplot(x='type', y='amount', data=data)
# Out:
# <Axes: xlabel='type', ylabel='amount'>

# %%
data['isFraud'].value_counts()
# Out:
# isFraud
# 0.0    1050075
# 1.0       1146
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 6))
sns.distplot(data['step'], bins=50)
# Out:
# /tmp/ipython-input-1113131929.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['step'], bins=50)
# <Axes: xlabel='step', ylabel='Density'>

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.apply(lambda x: pd.factorize(x)[0]).corr(),
			cmap='BrBG',
			fmt='.2f',
			linewidths=2,
			annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Data Preprocessing

# %%
type_new = pd.get_dummies(data['type'], drop_first=True)
data_new = pd.concat([data, type_new], axis=1)
data_new.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0
#
#    CASH_OUT  DEBIT  PAYMENT  TRANSFER
# 0     False  False     True     False
# ...

# %%
X = data_new.drop(['isFraud', 'type', 'nameOrig', 'nameDest'], axis=1)
y = data_new['isFraud']

# %%
X.shape, y.shape
# Out:
# ((1051222, 11), (1051222,))

# %% [markdown]
# Training and Testing

# %%
from sklearn.model_selection import train_test_split

# Drop rows with missing values
data_new.dropna(inplace=True)

# Define X and y after dropping rows with missing values
X = data_new.drop(['isFraud', 'type', 'nameOrig', 'nameDest'], axis=1)
y = data_new['isFraud']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Model Training

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score as ras
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
models = [LogisticRegression(), XGBClassifier(),
          RandomForestClassifier(n_estimators=7,
                                 criterion='entropy',
                                 random_state=7)]

for i in range(len(models)):
    models[i].fit(X_train, y_train)
    print(f'{models[i]} : ')

    train_preds = models[i].predict_proba(X_train)[:, 1]
    print('Training Accuracy : ', ras(y_train, train_preds))

    y_preds = models[i].predict_proba(X_test)[:, 1]
    print('Validation Accuracy : ', ras(y_test, y_preds))
    print()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression() :
# Training Accuracy :  0.8646185703631949
# Validation Accuracy :  0.8634491343655404
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
# ...

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = ConfusionMatrixDisplay.from_estimator(models[1], X_test, y_test)

cm.plot(cmap='Blues')

plt.show()
